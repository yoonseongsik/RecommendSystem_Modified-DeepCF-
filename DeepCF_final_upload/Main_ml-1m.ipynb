# %% [markdown]
# # Main

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Train CFNet-rl
# !python /content/drive/MyDrive/DeepCF/DMF_conv.py --dataset ml-1m --epoch 5 --lr 0.0001

# Train CFNet-ml
# !python /content/drive/MyDrive/DeepCF/MLP_conv.py --dataset ml-1m --epoch 5 --lr 0.001

# Train CFNet w/o pretrained weights
# !python /content/drive/MyDrive/DeepCF/CFNet_BPR.py --dataset ml-1m --epoch 5
# Out:
# DMF arguments: Namespace(bsz=256, dataset='ml-1m', epochs=5, itemLayers='[1024, 32]', lr=0.0001, nNeg=4, optim='adam', path='/content/drive/MyDrive/DeepCF/Data/', userLayers='[512, 32]')
# Use CUDA? True
# Load data: #user=6040, #item=3706, #train=994169, #test=6040 [14.2s]
# Init: HR=0.2159, NDCG=0.1148 [8.7s]
# Epoch 1: Loss=0.2866 [132.6s]
# Epoch 1: HR=0.6381, NDCG=0.3679 [8.8s]

# %%
# Train CFNet-rl
# !python /content/drive/MyDrive/DeepCF/DMF_ml.py --dataset ml-1m --epoch 5 --lr 0.0001

# Train CFNet-ml
# !python /content/drive/MyDrive/DeepCF/MLP_ml.py --dataset ml-1m --epoch 5 --lr 0.001

# Train CFNet w/o pretrained weights
# !python /content/drive/MyDrive/DeepCF/CFNet_ml.py --dataset ml-1m --epoch 5
