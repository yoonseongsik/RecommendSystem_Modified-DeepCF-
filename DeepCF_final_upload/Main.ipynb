# %% [markdown]
# # Main

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla P100-PCIE-16GB'

# %%
# user = 4011 item = 20517 (23612) train = 25603 (19991) test = 4011
# user = 4823 item = 36492 (42466) train = 36087 (35415) test = 4823

# Train CFNet-rl
# !python /content/drive/MyDrive/DeepCF/DMF.py --dataset Ratings --epoch 10 --lr 0.0001

# # Train CFNet-ml
# !python /content/drive/MyDrive/DeepCF/MLP.py --dataset Ratings --epoch 10 --lr 0.0001 

# # Train CFNet w/o pretrained weights
# !python /content/drive/MyDrive/DeepCF/CFNet.py --dataset Ratings --epoch 10
# Out:
# DeepCF arguments: Namespace(bsz=256, dataset='Ratings', dmf='', epochs=10, fcLayers='[512, 256, 128, 64]', itemLayers='[1024, 64]', lr=0.0001, mlp='', nNeg=4, optim='adam', path='/content/drive/MyDrive/DeepCF/Data/', userLayers='[512, 64]')
# Use CUDA? True
# Load data: #user=9571, #item=100083, #train=197303, #test=9571 [4.6s]
# tcmalloc: large alloc 3831578624 bytes == 0x6508000 @  0x7fa7c40a5001 0x7fa7c19b41af 0x7fa7c1a0ac23 0x7fa7c1a0ba87 0x7fa7c1aad823 0x5936cc 0x548c51 0x5127f1 0x593dd7 0x5118f8 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7fa7c3ca0c87 0x5b621a
# ...

# %%
# user = 4011 item = 20517 (23612) train = 25603 (19991) test = 4011
# user = 4823 item = 36492 (42466) train = 36087 (35415) test = 4823

# Train CFNet-rl
# !python /content/drive/MyDrive/DeepCF/DMF.py --dataset Ratings --epoch 10 --lr 0.0001

# # Train CFNet-ml
# !python /content/drive/MyDrive/DeepCF/MLP.py --dataset Ratings --epoch 10 --lr 0.0001 

# # Train CFNet w/o pretrained weights
# !python /content/drive/MyDrive/DeepCF/CFNet_outer_cnn.py --dataset Ratings --epoch 10
# Out:
# DeepCF arguments: Namespace(bsz=256, dataset='Ratings', dmf='', epochs=10, fcLayers='[512, 256, 128, 32]', itemLayers='[1024, 32]', lr=0.0001, mlp='', nNeg=4, optim='adam', path='/content/drive/MyDrive/DeepCF/Data/', userLayers='[512, 32]')
# Use CUDA? True
# Load data: #user=9571, #item=100083, #train=197303, #test=9571 [3.8s]
# tcmalloc: large alloc 3831578624 bytes == 0x6de4000 @  0x7fd9d0eb0001 0x7fd9ce7bf1af 0x7fd9ce815c23 0x7fd9ce816a87 0x7fd9ce8b8823 0x5936cc 0x548c51 0x5127f1 0x593dd7 0x5118f8 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7fd9d0aabc87 0x5b621a
# ...

# %%
# Train CFNet-rl
# !python /content/drive/MyDrive/DeepCF/DMF_conv.py --dataset Ratings --epoch 10 --lr 0.0001

# Train CFNet-ml 
# !python /content/drive/MyDrive/DeepCF/MLP_conv.py --dataset Ratings --epoch 10 --lr 0.0001

# Train CFNet w/o pretrained weights
# !python /content/drive/MyDrive/DeepCF/CFNet_outer_CNN_side.py --dataset Ratings --epoch 10 --lr 0.00005
# Out:
# DeepCF arguments: Namespace(bsz=256, dataset='Ratings', dmf='', epochs=10, fcLayers='[512, 256, 128, 32]', itemLayers='[1024, 32]', itemSIdataset='item_si.pkl', lr=5e-05, mlp='', nNeg=4, optim='adam', path='/content/drive/MyDrive/DeepCF/Data/', userLayers='[512, 32]', userSIdataset='user_si.pkl')
# Use CUDA? True
# Load data: #user=9571, #item=100083, #train=197303, #test=9571 [5.5s]
# tcmalloc: large alloc 3831578624 bytes == 0x9496000 @  0x7fcfa110b001 0x7fcf9e9da1af 0x7fcf9ea30c23 0x7fcf9ea31a87 0x7fcf9ead3823 0x5936cc 0x548c51 0x5127f1 0x593dd7 0x5118f8 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7fcfa0d06c87 0x5b621a
# ...
